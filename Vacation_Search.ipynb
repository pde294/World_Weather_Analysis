# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from requests) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from requests) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\parom\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
# %pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: six in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from gmaps) (7.19.0)
# Requirement already satisfied: ipython-genutils in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: setuptools>=18.5 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (41.2.0)
# Requirement already satisfied: backcall in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pygments in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (2.7.2)
# Requirement already satisfied: pickleshare in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: decorator in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: jedi>=0.10 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.2)
# Requirement already satisfied: jupyter-client in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-core in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.2.0)
# Requirement already satisfied: wcwidth in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (20.0.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (300)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.1.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.2)
# Requirement already satisfied: prometheus-client in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: jinja2 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.4.0)
# Requirement already satisfied: pywinpty>=0.5; os_name == "nt" in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: bleach in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.3.0)
# Requirement already satisfied: testpath in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: packaging in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.9)
# Requirement already satisfied: webencodings in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: pycparser in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\parom\appdata\local\programs\python\python37\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\parom\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key 

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
new_city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
new_city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      Takoradi   4.8845   -1.7554     78.66        84          12
# 1        1  Punta Arenas -53.1500  -70.9167     46.00        87          90
# 2        2     Mahebourg -20.4081   57.7000     77.00        94          75
# 3        3   New Norfolk -42.7826  147.0587     64.99        39          88
# 4        4      Necochea -38.5473  -58.7368     66.99        78          73
#
#    Wind Speed Country                 Date
# 0        6.62      GH  2021-02-22 06:03:31
# 1        9.22      CL  2021-02-22 06:03:31
# 2        4.61      MU  2021-02-22 06:03:32
# 3        7.00      AU  2021-02-22 06:03:32
# 4        5.01      AR  2021-02-22 06:03:32

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Get the maximum temperature.
max_temp = new_city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
    
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = new_city_data_df.loc[(new_city_data_df["Max Temp"] <= max_temp) & \
                                       (new_city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0     Takoradi   4.8845   -1.7554     78.66        84          12
# 2         2    Mahebourg -20.4081   57.7000     77.00        94          75
# 7         7        Kapaa  22.0752 -159.3190     73.99        83          40
# 8         8  Kloulklubed   7.0419  134.2556     84.20        74          75
# 13       13         Hilo  19.7297 -155.0900     71.60        83           1
# 15       15       Vanimo  -2.6741  141.3028     83.32        74          90
# 17       17  Bandarbeyla   9.4942   50.8122     77.52        60          94
# 19       19     Itaituba  -4.2761  -55.9836     73.31        91         100
# 22       22    Micheweni  -4.9667   39.8333     82.45        72         100
# 23       23     Souillac -20.5167   57.5167     77.00        94          75
#
#     Wind Speed Country                 Date
# 0         6.62      GH  2021-02-22 06:03:31
# 2         4.61      MU  2021-02-22 06:03:32
# 7        17.27      US  2021-02-22 06:03:35
# 8         6.91      PW  2021-02-22 06:03:35
# 13        3.44      US  2021-02-22 06:03:31
# 15       10.09      PG  2021-02-22 06:03:42
# 17       14.70      SO  2021-02-22 06:03:45
# 19        0.60      BR  2021-02-22 06:03:48
# 22        7.29      TZ  2021-02-22 06:03:55
# 23        4.61      MU  2021-02-22 06:03:55

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID       258
# City          258
# Lat           258
# Lng           258
# Max Temp      258
# Humidity      258
# Cloudiness    258
# Wind Speed    258
# Country       257
# Date          258
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
new_preferred_cities_df = preferred_cities_df.dropna()

# %%
new_preferred_cities_df.count()
# Out:
# City_ID       257
# City          257
# Lat           257
# Lng           257
# Max Temp      257
# Humidity      257
# Cloudiness    257
# Wind Speed    257
# Country       257
# Date          257
# dtype: int64

# %%
new_preferred_cities_df.head()
# Out:
#     City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0     Takoradi   4.8845   -1.7554     78.66        84          12
# 2         2    Mahebourg -20.4081   57.7000     77.00        94          75
# 7         7        Kapaa  22.0752 -159.3190     73.99        83          40
# 8         8  Kloulklubed   7.0419  134.2556     84.20        74          75
# 13       13         Hilo  19.7297 -155.0900     71.60        83           1
#
#     Wind Speed Country                 Date
# 0         6.62      GH  2021-02-22 06:03:31
# 2         4.61      MU  2021-02-22 06:03:32
# 7        17.27      US  2021-02-22 06:03:35
# 8         6.91      PW  2021-02-22 06:03:35
# 13        3.44      US  2021-02-22 06:03:31

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = new_preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#            City Country  Max Temp      Lat       Lng Hotel Name
# 0      Takoradi      GH     78.66   4.8845   -1.7554
# 2     Mahebourg      MU     77.00 -20.4081   57.7000
# 7         Kapaa      US     73.99  22.0752 -159.3190
# 8   Kloulklubed      PW     84.20   7.0419  134.2556
# 13         Hilo      US     71.60  19.7297 -155.0900
# 15       Vanimo      PG     83.32  -2.6741  141.3028
# 17  Bandarbeyla      SO     77.52   9.4942   50.8122
# 19     Itaituba      BR     73.31  -4.2761  -55.9836
# 22    Micheweni      TZ     82.45  -4.9667   39.8333
# 23     Souillac      MU     77.00 -20.5167   57.5167

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

    # 6c. Get latitude and longitude from DataFrame
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
clean_hotel_df.count()
# Out:
# City          257
# Country       257
# Max Temp      257
# Lat           257
# Lng           257
# Hotel Name    257
# dtype: int64

# %%
clean_hotel_df.head()
# Out:
#            City Country  Max Temp      Lat       Lng  \
# 0      Takoradi      GH     78.66   4.8845   -1.7554
# 2     Mahebourg      MU     77.00 -20.4081   57.7000
# 7         Kapaa      US     73.99  22.0752 -159.3190
# 8   Kloulklubed      PW     84.20   7.0419  134.2556
# 13         Hilo      US     71.60  19.7297 -155.0900
#
#                                 Hotel Name
# 0               Raybow International Hotel
# 2       Shandrani Beachcomber Resort & Spa
# 7   Sheraton Kauai Resort at Coconut Beach
# 8                  Storyboard Beach Resort
# 13                     Hilo Hawaiian Hotel

# %%
# 8a. Create the output File (CSV)
vacation_search_output_data_file = "Vacation Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(vacation_search_output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
